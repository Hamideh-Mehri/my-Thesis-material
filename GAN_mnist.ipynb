# %%
#load and preprocess data
import tensorflow as tf
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
train_images = (train_images-127.5)/127.5
with tf.device('/gpu:0'):
    BUFFER_SIZE = 60000
    BATCH_SIZE = 256
    # Batch and shuffle the data
    train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32')
test_images = (test_images-127.5)/127.5
with tf.device('/gpu:0'):
    BUFFER_SIZE = 10000
    BATCH_SIZE = 256
    # Batch and shuffle the data
    test_dataset = tf.data.Dataset.from_tensor_slices(test_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
# Out:
# 2023-01-31 20:30:25.871953: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-01-31 20:30:27.083663: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-31 20:30:27.084622: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-01-31 20:30:27.111233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-01-31 20:30:27.111509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:af:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-01-31 20:30:27.111528: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-01-31 20:30:27.113477: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-01-31 20:30:27.113540: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-01-31 20:30:27.115382: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-01-31 20:30:27.115698: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-01-31 20:30:27.117816: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-01-31 20:30:27.119035: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-01-31 20:30:27.122196: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-01-31 20:30:27.122834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2023-01-31 20:30:27.123402: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-31 20:30:27.124963: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-31 20:30:27.326484: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-01-31 20:30:27.326676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:af:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-01-31 20:30:27.326697: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-01-31 20:30:27.326719: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-01-31 20:30:27.326725: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-01-31 20:30:27.326731: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-01-31 20:30:27.326737: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-01-31 20:30:27.326743: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-01-31 20:30:27.326749: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-01-31 20:30:27.326755: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-01-31 20:30:27.327255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2023-01-31 20:30:27.327276: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-01-31 20:30:27.997636: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-31 20:30:27.997667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2023-01-31 20:30:27.997672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y
# 2023-01-31 20:30:27.997674: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N
# 2023-01-31 20:30:27.998423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 45381 MB memory) -> physical GPU (device: 0, name: Quadro RTX 8000, pci bus id: 0000:3b:00.0, compute capability: 7.5)
# 2023-01-31 20:30:27.999095: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 45390 MB memory) -> physical GPU (device: 1, name: Quadro RTX 8000, pci bus id: 0000:af:00.0, compute capability: 7.5)

# %%
#build generator
inp_gen = tf.keras.layers.Input(shape=(100,))
x = tf.keras.layers.Dense(7*7*128, use_bias = False)(inp_gen)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Reshape((7,7,128))(x)

x = tf.keras.layers.Conv2DTranspose(128, (5,5), strides=2, padding='same', use_bias=False)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)

x = tf.keras.layers.Conv2DTranspose(64, (5,5), strides=2, padding='same', use_bias=False)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)

x = tf.keras.layers.Conv2DTranspose(32, (5,5), strides=1, padding='same', use_bias=False)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)


out_gen = tf.keras.layers.Conv2DTranspose(1, (5,5), strides=1, padding='same', use_bias=False, activation='tanh')(x)
generator = tf.keras.models.Model(inp_gen, out_gen)

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense (Dense)                (None, 6272)              627200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6272)              25088
# _________________________________________________________________
# re_lu (ReLU)                 (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       409600
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 64)        204800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 32)        51200
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 1)         800
# =================================================================
# Total params: 1,319,584
# Trainable params: 1,306,592
# Non-trainable params: 12,992
# _________________________________________________________________

# %%
# create 150 noise vector of dim 100 randomly, and generate images via an untrained generator
with tf.device('/gpu:0'):
   noise = tf.random.normal([150, 100])    #batch_size = 1, latent_dim = 100
   generated_image = generator(noise)      #shape of generated image: [150, 28, 28, 1]
# Out:
# 2023-01-31 20:30:39.110851: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-01-31 20:30:39.305988: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7

# %%
#display one of the generated images
import matplotlib.pyplot as plt
plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %%
#build discriminator
inp_disc = tf.keras.layers.Input(shape=(28,28,1))

x = tf.keras.layers.LeakyReLU(alpha=0.2)(inp_disc)
x = tf.keras.layers.Conv2D(32, (5, 5), strides=(2, 2), padding='same')(x)

x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
x = tf.keras.layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same')(x)


x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
x = tf.keras.layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same')(x)

x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
x = tf.keras.layers.Conv2D(256, (5, 5), strides=(1, 1), padding='same')(x)

x = tf.keras.layers.Flatten()(x)
out_disc = tf.keras.layers.Dense(units=1)(x)

discriminator = tf.keras.models.Model(inp_disc, out_disc)

# %%
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 32)        832
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 64)          51264
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 128)         204928
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 256)         819456
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 4097
# =================================================================
# Total params: 1,080,577
# Trainable params: 1,080,577
# Non-trainable params: 0
# _________________________________________________________________

# %%
with tf.device('/gpu:0'):
    print(discriminator(generated_image[5:6]))
# Out:
# tf.Tensor([[2.1907945e-05]], shape=(1, 1), dtype=float32)

# %%
#loss function, optimizer, batch_size
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
lr = 2e-4
decay = 6e-8
generator_optimizer = tf.keras.optimizers.RMSprop(lr=lr, decay=decay)
discriminator_optimizer = tf.keras.optimizers.RMSprop(lr=lr * 0.5, decay=decay * 0.5)
noise_dim = 100
BATCH_SIZE = 256
train_iteration=25000

# %%
with tf.device('/gpu:0'):   
    real_label = tf.ones(shape=(BATCH_SIZE,1))
    fake_label = tf.zeros(shape=(BATCH_SIZE,1))

    loss_metric_disc = tf.keras.metrics.BinaryCrossentropy(from_logits=True)
    loss_metric_gen = tf.keras.metrics.BinaryCrossentropy(from_logits=True)
    
    acc_metric_disc = tf.keras.metrics.BinaryAccuracy()
    acc_metric_gen = tf.keras.metrics.BinaryAccuracy()
    

    plot_loss_disc = []
    plot_acc_disc = []
    plot_loss_gen = []
    plot_acc_gen = []

    for itr in range(train_iteration):
        image_batch = next(iter(train_dataset))
        noise_dim = 100
        noise = tf.random.normal([BATCH_SIZE, noise_dim])
        with tf.GradientTape() as disc_tape:
            generated_images = generator(noise, training=False)
            real_output = discriminator(image_batch, training=True)
            fake_output = discriminator(generated_images, training=True)

            real_loss = cross_entropy(tf.ones_like(real_output), real_output)
            fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
            disc_loss = real_loss + fake_loss
        gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_weights)
        discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_weights))

        noise = tf.random.normal([BATCH_SIZE, noise_dim])
        with tf.GradientTape() as gen_tape:
            generated_images = generator(noise, training=True)
            fake_output = discriminator(generated_images, training=False)

            gen_loss = cross_entropy(tf.ones_like(fake_output), fake_output)
        gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_weights)
        generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_weights))
        
        image_batch_val = next(iter(test_dataset))
        image_batch_val = tf.cast(image_batch_val, dtype=tf.dtypes.float32)
        noise_val = tf.random.normal([BATCH_SIZE, noise_dim])
        generated_images_val = generator(noise_val, training=True)
        generated_images_val = tf.cast(generated_images_val, dtype=tf.dtypes.float32)
        label = tf.concat((real_label, fake_label), axis=0)
        data = tf.concat((image_batch_val, generated_images_val), axis=0)
        logits_disc = discriminator(data, training=False)
        logits_gen = discriminator(generated_images_val, training=False)

        # Update training metric.
        loss_metric_disc.update_state(label, logits_disc)
        loss_metric_gen.update_state(real_label, logits_gen)
        acc_metric_disc.update_state(label, logits_disc)
        acc_metric_gen.update_state(real_label, logits_gen)
        
        if (itr + 1) % 100 == 0:
            loss_disc = loss_metric_disc.result()
            loss_gen = loss_metric_gen.result()
            
            acc_disc = acc_metric_disc.result()
            acc_gen = acc_metric_gen.result()
            

            plot_loss_disc.append(loss_disc)
            plot_loss_gen.append(loss_gen)

            plot_acc_disc.append(acc_disc)
            plot_acc_gen.append(acc_gen)
            
            print('train BinaryCrossentropyloss discriminator/generator acc at iteration %d: %.4f/%.4f ' % (itr+1, float(loss_disc), float(loss_gen)))
            print("Training accuracy discriminator/generator at iteration %d: %.4f/ %.4f" % (itr+1, float(acc_disc), float(acc_gen)))
            acc_metric_disc.reset_states()
            acc_metric_gen.reset_states()

            loss_metric_disc.reset_states()
            loss_metric_gen.reset_states()
# Out:
# train BinaryCrossentropyloss discriminator/generator acc at iteration 100: 1.6449/0.1673
# Training accuracy discriminator/generator at iteration 100: 0.4282/ 0.8872
# train BinaryCrossentropyloss discriminator/generator acc at iteration 200: 0.9424/0.4578
# Training accuracy discriminator/generator at iteration 200: 0.4144/ 0.4882
# train BinaryCrossentropyloss discriminator/generator acc at iteration 300: 0.6954/0.6915
# Training accuracy discriminator/generator at iteration 300: 0.5028/ 0.0058
# train BinaryCrossentropyloss discriminator/generator acc at iteration 400: 0.6843/0.7138
# Training accuracy discriminator/generator at iteration 400: 0.5013/ 0.0002
# train BinaryCrossentropyloss discriminator/generator acc at iteration 500: 0.6775/0.7233
# Training accuracy discriminator/generator at iteration 500: 0.5065/ 0.0011
# train BinaryCrossentropyloss discriminator/generator acc at iteration 600: 0.6812/0.7139
# Training accuracy discriminator/generator at iteration 600: 0.5061/ 0.0036
# train BinaryCrossentropyloss discriminator/generator acc at iteration 700: 0.6833/0.7138
# Training accuracy discriminator/generator at iteration 700: 0.5055/ 0.0041
# train BinaryCrossentropyloss discriminator/generator acc at iteration 800: 0.6819/0.7169
# Training accuracy discriminator/generator at iteration 800: 0.5061/ 0.0046
# train BinaryCrossentropyloss discriminator/generator acc at iteration 900: 0.6806/0.7191
# Training accuracy discriminator/generator at iteration 900: 0.5070/ 0.0069
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1000: 0.6790/0.7194
# Training accuracy discriminator/generator at iteration 1000: 0.5098/ 0.0104
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1100: 0.6783/0.7242
# Training accuracy discriminator/generator at iteration 1100: 0.5145/ 0.0152
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1200: 0.6777/0.7262
# Training accuracy discriminator/generator at iteration 1200: 0.5140/ 0.0230
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1300: 0.6783/0.7263
# Training accuracy discriminator/generator at iteration 1300: 0.5198/ 0.0209
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1400: 0.6799/0.7277
# Training accuracy discriminator/generator at iteration 1400: 0.5158/ 0.0235
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1500: 0.6796/0.7236
# Training accuracy discriminator/generator at iteration 1500: 0.5168/ 0.0252
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1600: 0.6808/0.7278
# Training accuracy discriminator/generator at iteration 1600: 0.5149/ 0.0256
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1700: 0.6823/0.7230
# Training accuracy discriminator/generator at iteration 1700: 0.5129/ 0.0235
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1800: 0.6832/0.7220
# Training accuracy discriminator/generator at iteration 1800: 0.5142/ 0.0257
# train BinaryCrossentropyloss discriminator/generator acc at iteration 1900: 0.6839/0.7230
# Training accuracy discriminator/generator at iteration 1900: 0.5114/ 0.0310
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2000: 0.6845/0.7219
# Training accuracy discriminator/generator at iteration 2000: 0.5123/ 0.0264
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2100: 0.6849/0.7214
# Training accuracy discriminator/generator at iteration 2100: 0.5113/ 0.0271
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2200: 0.6858/0.7221
# Training accuracy discriminator/generator at iteration 2200: 0.5093/ 0.0255
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2300: 0.6861/0.7214
# Training accuracy discriminator/generator at iteration 2300: 0.5085/ 0.0247
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2400: 0.6868/0.7209
# Training accuracy discriminator/generator at iteration 2400: 0.5070/ 0.0271
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2500: 0.6875/0.7191
# Training accuracy discriminator/generator at iteration 2500: 0.5068/ 0.0283
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2600: 0.6883/0.7174
# Training accuracy discriminator/generator at iteration 2600: 0.5077/ 0.0265
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2700: 0.6888/0.7186
# Training accuracy discriminator/generator at iteration 2700: 0.5068/ 0.0231
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2800: 0.6888/0.7167
# Training accuracy discriminator/generator at iteration 2800: 0.5056/ 0.0243
# train BinaryCrossentropyloss discriminator/generator acc at iteration 2900: 0.6900/0.7163
# Training accuracy discriminator/generator at iteration 2900: 0.5043/ 0.0241
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3000: 0.6909/0.7151
# Training accuracy discriminator/generator at iteration 3000: 0.5046/ 0.0238
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3100: 0.6904/0.7159
# Training accuracy discriminator/generator at iteration 3100: 0.5042/ 0.0197
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3200: 0.6909/0.7155
# Training accuracy discriminator/generator at iteration 3200: 0.5047/ 0.0231
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3300: 0.6908/0.7164
# Training accuracy discriminator/generator at iteration 3300: 0.5042/ 0.0244
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3400: 0.6913/0.7176
# Training accuracy discriminator/generator at iteration 3400: 0.5036/ 0.0246
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3500: 0.6926/0.7134
# Training accuracy discriminator/generator at iteration 3500: 0.5035/ 0.0255
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3600: 0.6914/0.7141
# Training accuracy discriminator/generator at iteration 3600: 0.5027/ 0.0205
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3700: 0.6937/0.7156
# Training accuracy discriminator/generator at iteration 3700: 0.5032/ 0.0201
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3800: 0.6924/0.7111
# Training accuracy discriminator/generator at iteration 3800: 0.5030/ 0.0230
# train BinaryCrossentropyloss discriminator/generator acc at iteration 3900: 0.6923/0.7152
# Training accuracy discriminator/generator at iteration 3900: 0.5036/ 0.0178
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4000: 0.6937/0.7159
# Training accuracy discriminator/generator at iteration 4000: 0.5036/ 0.0221
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4100: 0.6932/0.7131
# Training accuracy discriminator/generator at iteration 4100: 0.5022/ 0.0206
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4200: 0.6931/0.7141
# Training accuracy discriminator/generator at iteration 4200: 0.5027/ 0.0225
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4300: 0.6949/0.7125
# Training accuracy discriminator/generator at iteration 4300: 0.5034/ 0.0248
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4400: 0.6946/0.7118
# Training accuracy discriminator/generator at iteration 4400: 0.5013/ 0.0235
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4500: 0.6952/0.7112
# Training accuracy discriminator/generator at iteration 4500: 0.5023/ 0.0204
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4600: 0.6940/0.7137
# Training accuracy discriminator/generator at iteration 4600: 0.5015/ 0.0182
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4700: 0.6950/0.7117
# Training accuracy discriminator/generator at iteration 4700: 0.5025/ 0.0235
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4800: 0.6947/0.7125
# Training accuracy discriminator/generator at iteration 4800: 0.5022/ 0.0197
# train BinaryCrossentropyloss discriminator/generator acc at iteration 4900: 0.6953/0.7121
# Training accuracy discriminator/generator at iteration 4900: 0.5017/ 0.0229
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5000: 0.6959/0.7093
# Training accuracy discriminator/generator at iteration 5000: 0.5020/ 0.0244
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5100: 0.6969/0.7118
# Training accuracy discriminator/generator at iteration 5100: 0.5007/ 0.0234
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5200: 0.6953/0.7100
# Training accuracy discriminator/generator at iteration 5200: 0.5020/ 0.0200
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5300: 0.6961/0.7133
# Training accuracy discriminator/generator at iteration 5300: 0.5017/ 0.0226
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5400: 0.6953/0.7115
# Training accuracy discriminator/generator at iteration 5400: 0.5035/ 0.0216
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5500: 0.6953/0.7134
# Training accuracy discriminator/generator at iteration 5500: 0.5011/ 0.0193
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5600: 0.6971/0.7096
# Training accuracy discriminator/generator at iteration 5600: 0.5011/ 0.0267
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5700: 0.6963/0.7117
# Training accuracy discriminator/generator at iteration 5700: 0.5024/ 0.0197
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5800: 0.6966/0.7124
# Training accuracy discriminator/generator at iteration 5800: 0.5018/ 0.0226
# train BinaryCrossentropyloss discriminator/generator acc at iteration 5900: 0.6977/0.7110
# Training accuracy discriminator/generator at iteration 5900: 0.4995/ 0.0248
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6000: 0.6985/0.7106
# Training accuracy discriminator/generator at iteration 6000: 0.5006/ 0.0270
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6100: 0.7059/0.6972
# Training accuracy discriminator/generator at iteration 6100: 0.4990/ 0.0401
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6200: 0.6957/0.7160
# Training accuracy discriminator/generator at iteration 6200: 0.5025/ 0.0250
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6300: 0.6994/0.7062
# Training accuracy discriminator/generator at iteration 6300: 0.5026/ 0.0293
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6400: 0.7040/0.7022
# Training accuracy discriminator/generator at iteration 6400: 0.4973/ 0.0461
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6500: 0.7044/0.7010
# Training accuracy discriminator/generator at iteration 6500: 0.4985/ 0.0509
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6600: 0.7062/0.6979
# Training accuracy discriminator/generator at iteration 6600: 0.4985/ 0.0539
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6700: 0.7201/0.6823
# Training accuracy discriminator/generator at iteration 6700: 0.4937/ 0.1531
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6800: 0.7075/0.6999
# Training accuracy discriminator/generator at iteration 6800: 0.4982/ 0.0634
# train BinaryCrossentropyloss discriminator/generator acc at iteration 6900: 0.7645/0.6130
# Training accuracy discriminator/generator at iteration 6900: 0.4689/ 0.2604
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7000: 0.7381/0.6634
# Training accuracy discriminator/generator at iteration 7000: 0.4790/ 0.2215
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7100: 0.8098/0.5863
# Training accuracy discriminator/generator at iteration 7100: 0.4804/ 0.3818
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7200: 0.7807/0.6059
# Training accuracy discriminator/generator at iteration 7200: 0.4824/ 0.3734
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7300: 0.7718/0.6116
# Training accuracy discriminator/generator at iteration 7300: 0.4653/ 0.4131
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7400: 0.7767/0.6247
# Training accuracy discriminator/generator at iteration 7400: 0.4649/ 0.4063
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7500: 0.7239/0.7142
# Training accuracy discriminator/generator at iteration 7500: 0.5237/ 0.2990
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7600: 0.7523/0.7141
# Training accuracy discriminator/generator at iteration 7600: 0.5165/ 0.2742
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7700: 0.6773/0.7991
# Training accuracy discriminator/generator at iteration 7700: 0.5606/ 0.1841
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7800: 0.7079/0.7461
# Training accuracy discriminator/generator at iteration 7800: 0.5158/ 0.1606
# train BinaryCrossentropyloss discriminator/generator acc at iteration 7900: 0.7085/0.7294
# Training accuracy discriminator/generator at iteration 7900: 0.5279/ 0.2019
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8000: 0.7176/0.6624
# Training accuracy discriminator/generator at iteration 8000: 0.5364/ 0.3232
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8100: 0.7130/0.7511
# Training accuracy discriminator/generator at iteration 8100: 0.5163/ 0.1530
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8200: 0.7087/0.7354
# Training accuracy discriminator/generator at iteration 8200: 0.5100/ 0.1123
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8300: 0.7143/0.6738
# Training accuracy discriminator/generator at iteration 8300: 0.5165/ 0.2062
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8400: 0.7205/0.6791
# Training accuracy discriminator/generator at iteration 8400: 0.5159/ 0.2240
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8500: 0.7154/0.7233
# Training accuracy discriminator/generator at iteration 8500: 0.5186/ 0.1609
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8600: 0.7106/0.6896
# Training accuracy discriminator/generator at iteration 8600: 0.5230/ 0.1754
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8700: 0.7187/0.7210
# Training accuracy discriminator/generator at iteration 8700: 0.5021/ 0.1557
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8800: 0.7090/0.7307
# Training accuracy discriminator/generator at iteration 8800: 0.5051/ 0.1094
# train BinaryCrossentropyloss discriminator/generator acc at iteration 8900: 0.7069/0.7320
# Training accuracy discriminator/generator at iteration 8900: 0.5075/ 0.1011
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9000: 0.7107/0.7273
# Training accuracy discriminator/generator at iteration 9000: 0.5004/ 0.1005
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9100: 0.7062/0.7305
# Training accuracy discriminator/generator at iteration 9100: 0.5029/ 0.0763
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9200: 0.7082/0.7263
# Training accuracy discriminator/generator at iteration 9200: 0.5027/ 0.0812
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9300: 0.7092/0.7187
# Training accuracy discriminator/generator at iteration 9300: 0.5011/ 0.0799
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9400: 0.7097/0.7192
# Training accuracy discriminator/generator at iteration 9400: 0.4982/ 0.0784
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9500: 0.7095/0.7104
# Training accuracy discriminator/generator at iteration 9500: 0.5033/ 0.0966
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9600: 0.7086/0.7220
# Training accuracy discriminator/generator at iteration 9600: 0.5021/ 0.0786
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9700: 0.7092/0.7166
# Training accuracy discriminator/generator at iteration 9700: 0.4990/ 0.0740
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9800: 0.7144/0.6998
# Training accuracy discriminator/generator at iteration 9800: 0.4957/ 0.1049
# train BinaryCrossentropyloss discriminator/generator acc at iteration 9900: 0.7107/0.7176
# Training accuracy discriminator/generator at iteration 9900: 0.5015/ 0.0975
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10000: 0.7118/0.7162
# Training accuracy discriminator/generator at iteration 10000: 0.4962/ 0.0921
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10100: 0.7110/0.7018
# Training accuracy discriminator/generator at iteration 10100: 0.5027/ 0.1105
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10200: 0.7071/0.7262
# Training accuracy discriminator/generator at iteration 10200: 0.5040/ 0.0736
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10300: 0.7128/0.7167
# Training accuracy discriminator/generator at iteration 10300: 0.4941/ 0.0859
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10400: 0.7445/0.6058
# Training accuracy discriminator/generator at iteration 10400: 0.4907/ 0.2979
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10500: 0.7161/0.7201
# Training accuracy discriminator/generator at iteration 10500: 0.4973/ 0.1154
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10600: 0.7088/0.7294
# Training accuracy discriminator/generator at iteration 10600: 0.5018/ 0.0850
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10700: 0.7131/0.7188
# Training accuracy discriminator/generator at iteration 10700: 0.4976/ 0.0913
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10800: 0.7386/0.6333
# Training accuracy discriminator/generator at iteration 10800: 0.5041/ 0.3184
# train BinaryCrossentropyloss discriminator/generator acc at iteration 10900: 0.7214/0.6896
# Training accuracy discriminator/generator at iteration 10900: 0.5068/ 0.1587
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11000: 0.7501/0.6323
# Training accuracy discriminator/generator at iteration 11000: 0.4937/ 0.3012
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11100: 0.7136/0.7275
# Training accuracy discriminator/generator at iteration 11100: 0.5032/ 0.1044
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11200: 0.7099/0.7220
# Training accuracy discriminator/generator at iteration 11200: 0.5008/ 0.0954
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11300: 0.7122/0.7240
# Training accuracy discriminator/generator at iteration 11300: 0.4988/ 0.0974
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11400: 0.7087/0.7306
# Training accuracy discriminator/generator at iteration 11400: 0.5036/ 0.0846
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11500: 0.7128/0.7216
# Training accuracy discriminator/generator at iteration 11500: 0.4989/ 0.0945
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11600: 0.7089/0.7312
# Training accuracy discriminator/generator at iteration 11600: 0.5013/ 0.0823
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11700: 0.7221/0.6807
# Training accuracy discriminator/generator at iteration 11700: 0.4969/ 0.1602
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11800: 0.7136/0.7282
# Training accuracy discriminator/generator at iteration 11800: 0.5003/ 0.0943
# train BinaryCrossentropyloss discriminator/generator acc at iteration 11900: 0.7129/0.7256
# Training accuracy discriminator/generator at iteration 11900: 0.4973/ 0.0916
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12000: 0.7254/0.6781
# Training accuracy discriminator/generator at iteration 12000: 0.4925/ 0.1694
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12100: 0.7204/0.6988
# Training accuracy discriminator/generator at iteration 12100: 0.4967/ 0.1282
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12200: 0.7460/0.6495
# Training accuracy discriminator/generator at iteration 12200: 0.4936/ 0.2462
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12300: 0.7346/0.6802
# Training accuracy discriminator/generator at iteration 12300: 0.4953/ 0.2015
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12400: 0.7211/0.7257
# Training accuracy discriminator/generator at iteration 12400: 0.4989/ 0.1248
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12500: 0.7148/0.7295
# Training accuracy discriminator/generator at iteration 12500: 0.5000/ 0.1115
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12600: 0.7135/0.7304
# Training accuracy discriminator/generator at iteration 12600: 0.5021/ 0.0904
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12700: 0.7405/0.6380
# Training accuracy discriminator/generator at iteration 12700: 0.4929/ 0.2530
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12800: 0.7317/0.7045
# Training accuracy discriminator/generator at iteration 12800: 0.4896/ 0.1705
# train BinaryCrossentropyloss discriminator/generator acc at iteration 12900: 0.7123/0.7426
# Training accuracy discriminator/generator at iteration 12900: 0.5022/ 0.1005
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13000: 0.7158/0.7326
# Training accuracy discriminator/generator at iteration 13000: 0.4995/ 0.1020
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13100: 0.7158/0.7296
# Training accuracy discriminator/generator at iteration 13100: 0.4976/ 0.0959
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13200: 0.7189/0.7157
# Training accuracy discriminator/generator at iteration 13200: 0.4987/ 0.1196
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13300: 0.7163/0.7331
# Training accuracy discriminator/generator at iteration 13300: 0.4996/ 0.0957
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13400: 0.7171/0.7236
# Training accuracy discriminator/generator at iteration 13400: 0.4949/ 0.1083
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13500: 0.7121/0.7391
# Training accuracy discriminator/generator at iteration 13500: 0.4994/ 0.0875
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13600: 0.7208/0.7109
# Training accuracy discriminator/generator at iteration 13600: 0.4967/ 0.1318
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13700: 0.7629/0.6347
# Training accuracy discriminator/generator at iteration 13700: 0.4846/ 0.3137
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13800: 0.7415/0.6651
# Training accuracy discriminator/generator at iteration 13800: 0.4923/ 0.2463
# train BinaryCrossentropyloss discriminator/generator acc at iteration 13900: 0.7194/0.7336
# Training accuracy discriminator/generator at iteration 13900: 0.4986/ 0.1196
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14000: 0.7303/0.6843
# Training accuracy discriminator/generator at iteration 14000: 0.4959/ 0.2024
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14100: 0.7324/0.7109
# Training accuracy discriminator/generator at iteration 14100: 0.4934/ 0.1800
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14200: 0.7176/0.7364
# Training accuracy discriminator/generator at iteration 14200: 0.4994/ 0.1165
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14300: 0.7325/0.6785
# Training accuracy discriminator/generator at iteration 14300: 0.4978/ 0.2121
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14400: 0.7329/0.7005
# Training accuracy discriminator/generator at iteration 14400: 0.4926/ 0.1845
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14500: 0.7208/0.7429
# Training accuracy discriminator/generator at iteration 14500: 0.4997/ 0.1250
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14600: 0.7159/0.7471
# Training accuracy discriminator/generator at iteration 14600: 0.5006/ 0.1001
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14700: 0.7246/0.7159
# Training accuracy discriminator/generator at iteration 14700: 0.4992/ 0.1685
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14800: 0.7178/0.7422
# Training accuracy discriminator/generator at iteration 14800: 0.4999/ 0.1168
# train BinaryCrossentropyloss discriminator/generator acc at iteration 14900: 0.7221/0.7398
# Training accuracy discriminator/generator at iteration 14900: 0.4962/ 0.1203
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15000: 0.7177/0.7381
# Training accuracy discriminator/generator at iteration 15000: 0.5002/ 0.1070
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15100: 0.7639/0.6215
# Training accuracy discriminator/generator at iteration 15100: 0.4812/ 0.3444
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15200: 0.7544/0.6695
# Training accuracy discriminator/generator at iteration 15200: 0.4895/ 0.2849
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15300: 0.7294/0.7123
# Training accuracy discriminator/generator at iteration 15300: 0.5021/ 0.1836
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15400: 0.7222/0.7506
# Training accuracy discriminator/generator at iteration 15400: 0.5005/ 0.1313
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15500: 0.7458/0.6839
# Training accuracy discriminator/generator at iteration 15500: 0.4923/ 0.2446
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15600: 0.7215/0.7539
# Training accuracy discriminator/generator at iteration 15600: 0.5021/ 0.1241
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15700: 0.7206/0.7480
# Training accuracy discriminator/generator at iteration 15700: 0.5015/ 0.1190
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15800: 0.7691/0.6438
# Training accuracy discriminator/generator at iteration 15800: 0.4838/ 0.3230
# train BinaryCrossentropyloss discriminator/generator acc at iteration 15900: 0.7427/0.6821
# Training accuracy discriminator/generator at iteration 15900: 0.4953/ 0.2439
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16000: 0.7592/0.6456
# Training accuracy discriminator/generator at iteration 16000: 0.4881/ 0.3063
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16100: 0.7266/0.7531
# Training accuracy discriminator/generator at iteration 16100: 0.5022/ 0.1459
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16200: 0.7229/0.7478
# Training accuracy discriminator/generator at iteration 16200: 0.5022/ 0.1333
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16300: 0.7275/0.7453
# Training accuracy discriminator/generator at iteration 16300: 0.4971/ 0.1375
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16400: 0.7625/0.6301
# Training accuracy discriminator/generator at iteration 16400: 0.4877/ 0.3184
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16500: 0.7387/0.7071
# Training accuracy discriminator/generator at iteration 16500: 0.5008/ 0.2159
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16600: 0.7276/0.7515
# Training accuracy discriminator/generator at iteration 16600: 0.4999/ 0.1469
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16700: 0.7520/0.6814
# Training accuracy discriminator/generator at iteration 16700: 0.4951/ 0.2639
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16800: 0.7264/0.7596
# Training accuracy discriminator/generator at iteration 16800: 0.5000/ 0.1402
# train BinaryCrossentropyloss discriminator/generator acc at iteration 16900: 0.7498/0.6894
# Training accuracy discriminator/generator at iteration 16900: 0.4912/ 0.2405
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17000: 0.7292/0.7565
# Training accuracy discriminator/generator at iteration 17000: 0.5013/ 0.1499
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17100: 0.7304/0.7361
# Training accuracy discriminator/generator at iteration 17100: 0.4980/ 0.1723
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17200: 0.7377/0.7356
# Training accuracy discriminator/generator at iteration 17200: 0.4905/ 0.1763
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17300: 0.7202/0.7709
# Training accuracy discriminator/generator at iteration 17300: 0.5030/ 0.1184
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17400: 0.7252/0.7618
# Training accuracy discriminator/generator at iteration 17400: 0.4976/ 0.1371
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17500: 0.8202/0.5583
# Training accuracy discriminator/generator at iteration 17500: 0.4858/ 0.4695
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17600: 0.7653/0.7032
# Training accuracy discriminator/generator at iteration 17600: 0.4954/ 0.2948
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17700: 0.7396/0.7405
# Training accuracy discriminator/generator at iteration 17700: 0.4994/ 0.2039
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17800: 0.7242/0.7771
# Training accuracy discriminator/generator at iteration 17800: 0.5045/ 0.1277
# train BinaryCrossentropyloss discriminator/generator acc at iteration 17900: 0.7312/0.7577
# Training accuracy discriminator/generator at iteration 17900: 0.4996/ 0.1479
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18000: 0.7535/0.6822
# Training accuracy discriminator/generator at iteration 18000: 0.4964/ 0.2591
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18100: 0.7537/0.7385
# Training accuracy discriminator/generator at iteration 18100: 0.4955/ 0.2620
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18200: 0.7329/0.7650
# Training accuracy discriminator/generator at iteration 18200: 0.4991/ 0.1574
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18300: 0.7319/0.7472
# Training accuracy discriminator/generator at iteration 18300: 0.5021/ 0.1745
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18400: 0.7365/0.7262
# Training accuracy discriminator/generator at iteration 18400: 0.5029/ 0.1932
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18500: 0.7316/0.7683
# Training accuracy discriminator/generator at iteration 18500: 0.5002/ 0.1599
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18600: 0.7337/0.7472
# Training accuracy discriminator/generator at iteration 18600: 0.5017/ 0.1805
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18700: 0.7433/0.7265
# Training accuracy discriminator/generator at iteration 18700: 0.4951/ 0.2245
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18800: 0.7274/0.7796
# Training accuracy discriminator/generator at iteration 18800: 0.5061/ 0.1416
# train BinaryCrossentropyloss discriminator/generator acc at iteration 18900: 0.7354/0.7509
# Training accuracy discriminator/generator at iteration 18900: 0.5012/ 0.1716
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19000: 0.7256/0.7767
# Training accuracy discriminator/generator at iteration 19000: 0.5052/ 0.1343
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19100: 0.7275/0.7722
# Training accuracy discriminator/generator at iteration 19100: 0.5033/ 0.1336
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19200: 0.7341/0.7634
# Training accuracy discriminator/generator at iteration 19200: 0.4919/ 0.1521
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19300: 0.7438/0.7251
# Training accuracy discriminator/generator at iteration 19300: 0.4949/ 0.2041
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19400: 0.7367/0.7537
# Training accuracy discriminator/generator at iteration 19400: 0.4996/ 0.1779
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19500: 0.7636/0.6880
# Training accuracy discriminator/generator at iteration 19500: 0.4906/ 0.2840
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19600: 0.7296/0.7781
# Training accuracy discriminator/generator at iteration 19600: 0.5057/ 0.1429
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19700: 0.7323/0.7661
# Training accuracy discriminator/generator at iteration 19700: 0.5040/ 0.1524
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19800: 0.7366/0.7528
# Training accuracy discriminator/generator at iteration 19800: 0.4997/ 0.1738
# train BinaryCrossentropyloss discriminator/generator acc at iteration 19900: 0.7420/0.7298
# Training accuracy discriminator/generator at iteration 19900: 0.4988/ 0.2142
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20000: 0.7379/0.7659
# Training accuracy discriminator/generator at iteration 20000: 0.5020/ 0.1740
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20100: 0.7326/0.7727
# Training accuracy discriminator/generator at iteration 20100: 0.5045/ 0.1550
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20200: 0.7319/0.7800
# Training accuracy discriminator/generator at iteration 20200: 0.5002/ 0.1470
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20300: 0.7310/0.7813
# Training accuracy discriminator/generator at iteration 20300: 0.5017/ 0.1372
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20400: 0.7457/0.7356
# Training accuracy discriminator/generator at iteration 20400: 0.4967/ 0.2045
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20500: 0.7601/0.7105
# Training accuracy discriminator/generator at iteration 20500: 0.4915/ 0.2784
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20600: 0.7677/0.7247
# Training accuracy discriminator/generator at iteration 20600: 0.4935/ 0.2734
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20700: 0.7348/0.7850
# Training accuracy discriminator/generator at iteration 20700: 0.5053/ 0.1732
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20800: 0.7278/0.7976
# Training accuracy discriminator/generator at iteration 20800: 0.5092/ 0.1387
# train BinaryCrossentropyloss discriminator/generator acc at iteration 20900: 0.7432/0.7665
# Training accuracy discriminator/generator at iteration 20900: 0.4979/ 0.1900
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21000: 0.7613/0.7151
# Training accuracy discriminator/generator at iteration 21000: 0.4896/ 0.2616
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21100: 0.7745/0.7041
# Training accuracy discriminator/generator at iteration 21100: 0.5078/ 0.3205
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21200: 0.7464/0.7827
# Training accuracy discriminator/generator at iteration 21200: 0.5016/ 0.1911
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21300: 0.7367/0.7898
# Training accuracy discriminator/generator at iteration 21300: 0.5087/ 0.1691
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21400: 0.7323/0.8074
# Training accuracy discriminator/generator at iteration 21400: 0.5088/ 0.1453
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21500: 0.7387/0.7806
# Training accuracy discriminator/generator at iteration 21500: 0.5029/ 0.1651
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21600: 0.7343/0.8137
# Training accuracy discriminator/generator at iteration 21600: 0.5030/ 0.1486
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21700: 0.7544/0.7408
# Training accuracy discriminator/generator at iteration 21700: 0.4946/ 0.2323
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21800: 0.7353/0.7972
# Training accuracy discriminator/generator at iteration 21800: 0.5063/ 0.1587
# train BinaryCrossentropyloss discriminator/generator acc at iteration 21900: 0.7364/0.7996
# Training accuracy discriminator/generator at iteration 21900: 0.5011/ 0.1517
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22000: 0.7448/0.7636
# Training accuracy discriminator/generator at iteration 22000: 0.5016/ 0.1887
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22100: 0.7449/0.7764
# Training accuracy discriminator/generator at iteration 22100: 0.4964/ 0.1855
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22200: 0.7304/0.8173
# Training accuracy discriminator/generator at iteration 22200: 0.5091/ 0.1427
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22300: 0.7480/0.7772
# Training accuracy discriminator/generator at iteration 22300: 0.4987/ 0.1905
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22400: 0.7550/0.7542
# Training accuracy discriminator/generator at iteration 22400: 0.5012/ 0.2432
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22500: 0.7436/0.7925
# Training accuracy discriminator/generator at iteration 22500: 0.4996/ 0.1784
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22600: 0.7440/0.7710
# Training accuracy discriminator/generator at iteration 22600: 0.5089/ 0.2131
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22700: 0.7553/0.7529
# Training accuracy discriminator/generator at iteration 22700: 0.4979/ 0.2379
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22800: 0.7826/0.7261
# Training accuracy discriminator/generator at iteration 22800: 0.4953/ 0.2841
# train BinaryCrossentropyloss discriminator/generator acc at iteration 22900: 0.7636/0.7720
# Training accuracy discriminator/generator at iteration 22900: 0.5047/ 0.2507
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23000: 0.7470/0.7894
# Training accuracy discriminator/generator at iteration 23000: 0.5071/ 0.2069
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23100: 0.7373/0.8167
# Training accuracy discriminator/generator at iteration 23100: 0.5094/ 0.1581
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23200: 0.7539/0.7796
# Training accuracy discriminator/generator at iteration 23200: 0.4993/ 0.2213
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23300: 0.7730/0.7265
# Training accuracy discriminator/generator at iteration 23300: 0.4960/ 0.3021
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23400: 0.7486/0.7878
# Training accuracy discriminator/generator at iteration 23400: 0.5121/ 0.2205
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23500: 0.7367/0.8390
# Training accuracy discriminator/generator at iteration 23500: 0.5143/ 0.1545
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23600: 0.7416/0.8072
# Training accuracy discriminator/generator at iteration 23600: 0.5135/ 0.1862
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23700: 0.7361/0.8361
# Training accuracy discriminator/generator at iteration 23700: 0.5125/ 0.1543
# train BinaryCrossentropyloss discriminator/generator acc at iteration 23800: 0.7480/0.8007
# Training accuracy discriminator/generator at iteration 23800: 0.5046/ 0.1879

# %%
with tf.device('/gpu:0'):
   train_iteration=25000

   real_label = tf.ones(shape=(BATCH_SIZE,1))
   fake_label = tf.zeros(shape=(BATCH_SIZE,1))

   acc_metric_disc = tf.keras.metrics.BinaryCrossentropy(from_logits=True)
   acc_metric_gen = tf.keras.metrics.BinaryCrossentropy(from_logits=True)
   loss_avg_disc = tf.keras.metrics.Mean()
   loss_avg_gen = tf.keras.metrics.Mean()

   plot_loss_disc = []
   plot_acc_disc = []
   plot_loss_gen = []
   plot_acc_gen = []

   for itr in range(train_iteration):
       image_batch = next(iter(train_dataset))
       noise_dim = 100
       noise = tf.random.normal([BATCH_SIZE, noise_dim])
       with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
           generated_images = generator(noise, training=True)
           real_output = discriminator(image_batch, training=True)
           fake_output = discriminator(generated_images, training=True)

           gen_loss = cross_entropy(tf.ones_like(fake_output), fake_output)
           real_loss = cross_entropy(tf.ones_like(real_output), real_output)
           fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
           disc_loss = real_loss + fake_loss
       gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_weights)
       gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_weights)

       discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_weights))
       generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_weights))
    
       image_batch = tf.cast(image_batch, dtype=tf.dtypes.float32)
       generated_images = tf.cast(generated_images, dtype=tf.dtypes.float32)
       label = tf.concat((real_label, fake_label), axis=0)
       data = tf.concat((image_batch, generated_images), axis=0)
       logits_disc = discriminator(data, training=False)
       logits_gen = discriminator(generated_images, training=False)
    
       # Update training metric.
       acc_metric_disc.update_state(label, logits_disc)
       acc_metric_gen.update_state(real_label, logits_gen)
       loss_avg_disc.update_state(disc_loss)
       loss_avg_gen.update_state(gen_loss)
       if (itr + 1) % 100 == 0:
           acc_disc = acc_metric_disc.result()
           acc_gen = acc_metric_gen.result()

           loss_disc = loss_avg_disc.result()
           loss_gen = loss_avg_gen.result()

           plot_loss_disc.append(loss_disc)
           plot_loss_gen.append(loss_gen)

           plot_acc_disc.append(acc_disc)
           plot_acc_gen.append(acc_gen)
           
           print('train acc discriminator/generator acc at iteration %d: %.4f/%.4f ' % (itr+1, float(acc_disc), float(acc_gen)))
           #print("Training loss discriminator/generator at iteration %d: %.4f/ %.4f" % (itr+1, float(train_loss_disc), float(train_loss_gen)))
           acc_metric_disc.reset_states()
           acc_metric_gen.reset_states()

           loss_avg_disc.reset_states()
           loss_avg_gen.reset_states()
# Out:
# train acc discriminator/generator acc at iteration 100: 0.5265/0.9753
# train acc discriminator/generator acc at iteration 200: 0.6465/0.7718
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4049429/1140198617.py in <module>
#      16
#      17    for itr in range(train_iteration):
# ---> 18        image_batch = next(iter(train_dataset))
#      19        noise_dim = 100
#      20        noise = tf.random.normal([BATCH_SIZE, noise_dim])
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     420     if context.executing_eagerly() or ops.inside_function():
#     421       with ops.colocate_with(self._variant_tensor):
# --> 422         return iterator_ops.OwnedIterator(self)
#     423     else:
#     424       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     680       if (components is not None or element_spec is not None):
#     681         raise ValueError(error_message)
# --> 682       self._create_iterator(dataset)
#     683
#     684   def _create_iterator(self, dataset):
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     684   def _create_iterator(self, dataset):
#     685     # pylint: disable=protected-access
# --> 686     dataset = dataset._apply_options()
#     687
#     688     # Store dataset reference to ensure that dataset is alive when this iterator
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in _apply_options(self)
#     397       dataset = _OptimizeDataset(dataset, graph_rewrites.enabled,
#     398                                  graph_rewrites.disabled,
# --> 399                                  graph_rewrites.default, graph_rewrite_configs)
#     400
#     401     # (4) Apply stats aggregator options
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, optimizations_enabled, optimizations_disabled, optimizations_default, optimization_configs)
#    4581         self._optimizations_default,
#    4582         optimization_configs=optimization_configs,
# -> 4583         **self._flat_structure)
#    4584
#    4585     super(_OptimizeDataset, self).__init__(input_dataset, variant_tensor)
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/ops/gen_dataset_ops.py in optimize_dataset_v2(input_dataset, optimizations_enabled, optimizations_disabled, optimizations_default, output_types, output_shapes, optimization_configs, name)
#    4023         optimizations_disabled, optimizations_default, "output_types",
#    4024         output_types, "output_shapes", output_shapes, "optimization_configs",
# -> 4025         optimization_configs)
#    4026       return _result
#    4027     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
generator.save('mnistgenerator')
# Out:
# 2023-01-16 14:43:36.814596: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: mnistgenerator/assets

# %%
import tensorflow as tf
generator = tf.keras.models.load_model('mnistgenerator')
# Out:
# 2023-05-09 19:16:14.296129: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_1888563/110696883.py in <module>
#       1 import tensorflow as tf
# ----> 2 generator = tf.keras.models.load_model('mnistgenerator')
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     209       filepath = path_to_string(filepath)
#     210       if isinstance(filepath, six.string_types):
# --> 211         loader_impl.parse_saved_model(filepath)
#     212         return saved_model_load.load(filepath, compile, options)
#     213
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 114                    constants.SAVED_MODEL_FILENAME_PB))
#     115
#     116
#
# OSError: SavedModel file does not exist at: mnistgenerator/{saved_model.pbtxt|saved_model.pb}

# %%
with tf.device('/gpu:0'):
   tf.random.set_seed(5)
   noise = tf.random.normal([600, 100])    #batch_size = 1, latent_dim = 100
   generated_image = generator(noise)

# %%
tf.random.set_seed(4)
noise = tf.random.normal([600, 100]) 
generated_image2 = generator(noise)

# %%
g = tf.concat([generated_image, generated_image2], axis=0)

# %%
g.shape
# Out:
# TensorShape([1200, 28, 28, 1])

# %%
type(generated_image), generated_image.shape
# Out:
# (tensorflow.python.framework.ops.EagerTensor, TensorShape([600, 28, 28, 1]))

# %%
batch = 200
generated_images = None
for i in range(300):
    tf.random.set_seed(i)
    noise = tf.random.normal([batch, 100])
    generated_image = generator(noise)
    if generated_images is None:
        generated_images = generated_image
    else:
        generated_images = tf.concat([generated_images, generated_image], axis=0)

# %%
generated_images.shape
# Out:
# TensorShape([60000, 28, 28, 1])

# %%
tf.reduce_min(generated_images)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-1.0>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))

for i in range(100):
  plt.subplot(10,10,i+1)
  plt.imshow(generated_image[i+200, :, :, 0], cmap='gray')
  plt.axis('off')

# %%
plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %%
#construct classification model
import tensorflow as tf
inp = tf.keras.layers.Input(shape=(28, 28, 1))
x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='valid')(inp)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='valid')(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=1, padding='valid')(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, strides=1, padding='valid')(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x)
x = tf.keras.layers.BatchNormalization()(x)

x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, strides=1, padding='valid')(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(x)
x = tf.keras.layers.BatchNormalization()(x)
 
x = tf.keras.layers.Flatten()(x)

x = tf.keras.layers.Dense(units=512, activation='relu')(x)

x = tf.keras.layers.Dense(units=10, activation='softmax')(x)

# %%
model = tf.keras.models.Model(inp, x)

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
import tensorflow as tf
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
train_images = (train_images-127.5)/127.5

# %%
history = model.fit(train_images, train_labels, batch_size=128,  epochs=20, validation_split=0.2)

# %%
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32')
test_images = (test_images-127.5)/127.5
loss_accuracy = model.evaluate(test_images, test_labels, verbose=0)

# %%
loss_accuracy[1]
# Out:
# 0.9919000267982483

# %%
train_images.shape, generated_images.shape
# Out:
# ((60000, 28, 28, 1), TensorShape([60000, 28, 28, 1]))

# %%
generated_images[0:200].shape
# Out:
# TensorShape([200, 28, 28, 1])

# %%
tf.reduce_sum(model(generated_images[0:10])[0])
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.0>

# %%
i = 0
prob = model(generated_images[200*i:200*(i+1)])
prob.shape, type(prob)
# Out:
# (TensorShape([200, 10]), tensorflow.python.framework.ops.EagerTensor)

# %%
probs = None
for i in range(300):
    prob = model(generated_images[200*i:200*(i+1)])
    if probs is None:
        probs = prob
    else:
        probs = tf.concat([probs, prob], axis=0)
probs.shape
# Out:
# TensorShape([60000, 10])

# %%
p_yx = probs
p_y = tf.expand_dims(tf.reduce_mean(p_yx, axis=0), 0)
eps=1E-16
# kl divergence for each image
kl_d = p_yx * (tf.math.log(p_yx + eps) - tf.math.log(p_y + eps))
sum_kl_d = tf.reduce_sum(kl_d, axis=1)
avg_kl_d = tf.reduce_mean(sum_kl_d)
is_score = tf.math.exp(avg_kl_d)
is_score
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=9.471862>

# %%
import tensorflow as tf
inp_gen = tf.keras.layers.Input(shape=(100,))
x = tf.keras.layers.Dense(7*7*128, use_bias = False)(inp_gen)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)
x = tf.keras.layers.Reshape((7,7,128))(x)

x = tf.keras.layers.Conv2DTranspose(128, (5,5), strides=2, padding='same', use_bias=False)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)

x = tf.keras.layers.Conv2DTranspose(64, (5,5), strides=2, padding='same', use_bias=False)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)

x = tf.keras.layers.Conv2DTranspose(32, (5,5), strides=1, padding='same', use_bias=False)(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.ReLU()(x)


out_gen = tf.keras.layers.Conv2DTranspose(1, (5,5), strides=1, padding='same', use_bias=False, activation='tanh')(x)

# %%
generator = tf.keras.models.Model(inp_gen, out_gen)

# %%
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense (Dense)                (None, 6272)              627200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6272)              25088
# _________________________________________________________________
# re_lu (ReLU)                 (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       409600
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 64)        204800
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 32)        51200
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 1)         800
# =================================================================
# Total params: 1,319,584
# Trainable params: 1,306,592
# Non-trainable params: 12,992
# _________________________________________________________________

# %%
class DCGAN(object):
   def __init__(self, datasource, latent_dim, *initializer):
      self.datasource = datasource
      self.latentdim = latent_dim
      #self.input_dims = [64, 64, 3] if self.datasource == 'tiny-imagenet' else [32, 32, 3]
      self.convinitializer = initializer[0]
      self.denseinitializer = initializer[1]
   def construct_weights(self, trainable=True):
       weight = {}
       if self.datasource == 'mnist':
          DeconvInput = 7 * 7 * 128
       weight['w1_fc'] = tf.Variable(self.denseinitializer(shape=(self.latentdim, DeconvInput)),name='w1', trainable=trainable)
       weight['w2_Dconv'] = tf.Variable(self.convinitializer(shape=(5,5,128,128)), name='w2', trainable=trainable)
       weight['w3_Dconv'] = tf.Variable(self.convinitializer(shape=(5,5,64,128)), name='w3', trainable=trainable)
       weight['w4_Dconv'] = tf.Variable(self.convinitializer(shape=(5,5,32,64)), name='w4', trainable=trainable)
       weight['w5_Dconv'] = tf.Variable(self.convinitializer(shape=(5,5,1,32)), name='w5', trainable=trainable)
       return weight

# %%
import tensorflow as tf
class ConvTwoTranspose(tf.keras.layers.Layer):
    def __init__(self, weight, outputshape, stridesList, padding):
        super(ConvTwoTranspose,self).__init__()
        self.w = tf.Variable(initial_value=weight, trainable=True)
        self.outputshape = outputshape
        self.strides = stridesList
        self.padding = padding

    def call(self, inputs):
        return tf.nn.conv2d_transpose(inputs, self.w, self.outputshape, self.strides, self.padding) 

class DenseGan(tf.keras.layers.Layer):
    def __init__(self, weight, activation):
        super(DenseGan, self).__init__()
        self.w = tf.Variable(initial_value=weight, trainable=True)
        self.activation = activation
    def call(self,input):
        return self.activation(tf.matmul(input, self.w))
# Out:
# 2023-01-19 00:47:13.532238: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
initializer1 = tf.initializers.variance_scaling()
initializer2 = tf.initializers.variance_scaling()
net = DCGAN('mnist', 100, initializer1, initializer2)
weight = net.construct_weights()
# Out:
# 2023-01-19 00:47:16.682654: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-19 00:47:16.684217: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-01-19 00:47:16.715838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-01-19 00:47:16.716138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:af:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-01-19 00:47:16.716150: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-01-19 00:47:16.717552: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-01-19 00:47:16.717593: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-01-19 00:47:16.718877: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-01-19 00:47:16.719088: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-01-19 00:47:16.720527: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-01-19 00:47:16.721281: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-01-19 00:47:16.724280: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-01-19 00:47:16.724939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2023-01-19 00:47:16.725461: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-19 00:47:16.726767: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-19 00:47:16.899922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:3b:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-01-19 00:47:16.900095: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:af:00.0 name: Quadro RTX 8000 computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 47.46GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-01-19 00:47:16.900113: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-01-19 00:47:16.900135: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-01-19 00:47:16.900142: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-01-19 00:47:16.900148: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-01-19 00:47:16.900154: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-01-19 00:47:16.900160: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-01-19 00:47:16.900166: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-01-19 00:47:16.900172: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-01-19 00:47:16.900661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2023-01-19 00:47:16.900685: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_2334829/2398676907.py in <module>
#       2 initializer2 = tf.initializers.variance_scaling()
#       3 net = DCGAN('mnist', 100, initializer1, initializer2)
# ----> 4 weight = net.construct_weights()
#
# /tmp/ipykernel_2334829/2935690908.py in construct_weights(self, trainable)
#      10        if self.datasource == 'mnist':
#      11           DeconvInput = 7 * 7 * 128
# ---> 12        weight['w1_fc'] = tf.Variable(self.denseinitializer(shape=(self.latentdim, DeconvInput)),name='w1', trainable=trainable)
#      13        weight['w2_Dconv'] = tf.Variable(self.convinitializer(shape=(5,5,128,128)), name='w2', trainable=trainable)
#      14        weight['w3_Dconv'] = tf.Variable(self.convinitializer(shape=(5,5,64,128)), name='w3', trainable=trainable)
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/keras/initializers/initializers_v2.py in __call__(self, shape, dtype, **kwargs)
#     408     """
#     409     return super(VarianceScaling, self).__call__(
# --> 410         shape, dtype=_get_dtype(dtype), **kwargs)
#     411
#     412
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/ops/init_ops_v2.py in __call__(self, shape, dtype, **kwargs)
#     592       # constant from scipy.stats.truncnorm.std(a=-2, b=2, loc=0., scale=1.)
#     593       stddev = math.sqrt(scale) / .87962566103423978
# --> 594       return self._random_generator.truncated_normal(shape, 0.0, stddev, dtype)
#     595     elif self.distribution == "untruncated_normal":
#     596       stddev = math.sqrt(scale)
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/ops/init_ops_v2.py in truncated_normal(self, shape, mean, stddev, dtype)
#    1089       op = random_ops.truncated_normal
#    1090     return op(
# -> 1091         shape=shape, mean=mean, stddev=stddev, dtype=dtype, seed=self.seed)
#    1092
#    1093 # Compatibility aliases
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/ops/random_ops.py in truncated_normal(shape, mean, stddev, dtype, seed, name)
#     190   """
#     191   with ops.name_scope(name, "truncated_normal", [shape, mean, stddev]) as name:
# --> 192     shape_tensor = tensor_util.shape_tensor(shape)
#     193     mean_tensor = ops.convert_to_tensor(mean, dtype=dtype, name="mean")
#     194     stddev_tensor = ops.convert_to_tensor(stddev, dtype=dtype, name="stddev")
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/framework/tensor_util.py in shape_tensor(shape)
#    1033       # not convertible to Tensors because of mixed content.
#    1034       shape = tuple(map(tensor_shape.dimension_value, shape))
# -> 1035   return ops.convert_to_tensor(shape, dtype=dtype, name="shape")
#    1036
#    1037
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     337                                          as_ref=False):
#     338   _ = as_ref
# --> 339   return constant(v, dtype=dtype, name=name)
#     340
#     341
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      95     except AttributeError:
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# ---> 97   ctx.ensure_initialized()
#      98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#
# ~/miniconda3/envs/mainenv/lib/python3.7/site-packages/tensorflow/python/eager/context.py in ensure_initialized(self)
#     524         if self._use_tfrt is not None:
#     525           pywrap_tfe.TFE_ContextOptionsSetTfrt(opts, self._use_tfrt)
# --> 526         context_handle = pywrap_tfe.TFE_NewContext(opts)
#     527       finally:
#     528         pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# InternalError: CUDA runtime implicit initialization on GPU:0 failed. Status: out of memory

# %%
batch_size = 250
inp = tf.keras.layers.Input(shape= (100,))
fc1 = DenseGan(weight['w1_fc'], tf.keras.activations.linear)(inp)
batchnorm1 = tf.keras.layers.BatchNormalization()(fc1)
Rel1 = tf.keras.layers.ReLU()(batchnorm1)
DeconvInput = tf.keras.layers.Reshape((7,7,128))(Rel1)

Deconv2 = ConvTwoTranspose(weight['w2_Dconv'], [batch_size,14,14,128],[1,2,2,1],'SAME')(DeconvInput)
batchnorm2 = tf.keras.layers.BatchNormalization()(Deconv2)
Rel2 = tf.keras.layers.ReLU()(batchnorm2)

Deconv3 = ConvTwoTranspose(weight['w3_Dconv'], [batch_size,28,28,64],[1,2,2,1],'SAME')(Rel2)
batchnorm3 = tf.keras.layers.BatchNormalization()(Deconv3)
Rel3 = tf.keras.layers.ReLU()(batchnorm3)

Deconv4 = ConvTwoTranspose(weight['w4_Dconv'], [batch_size,28,28,32],[1,1,1,1],'SAME')(Rel3)
batchnorm4 = tf.keras.layers.BatchNormalization()(Deconv4)
Rel4 = tf.keras.layers.ReLU()(batchnorm4)

Deconv5 = ConvTwoTranspose(weight['w5_Dconv'], [batch_size,28,28,1],[1,1,1,1],'SAME')(Rel4)
out = tf.keras.activations.tanh(Deconv5)

model = tf.keras.models.Model(inp, out)

# %%
tf.random.set_seed(5)
noise = tf.random.normal([250, 100])

# %%
model2 = tf.keras.models.Model(inp, DeconvInput)
model2(noise)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2334829/41953451.py in <module>
# ----> 1 model2 = tf.keras.models.Model(inp, DeconvInput)
#       2 model2(noise)
#
# NameError: name 'tf' is not defined

# %%
with tf.device('/gpu:1'):
    model(noise)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        [(None, 100)]             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 6272)              627200
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 6272)              25088
# _________________________________________________________________
# re_lu_30 (ReLU)              (None, 6272)              0
# _________________________________________________________________
# reshape_16 (Reshape)         (None, 7, 7, 128)         0
# _________________________________________________________________
# conv_two_transpose_23 (ConvT (None, 14, 14, 128)       409600
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 14, 14, 128)       512
# _________________________________________________________________
# re_lu_31 (ReLU)              (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_two_transpose_24 (ConvT (None, 28, 28, 64)        204800
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 28, 28, 64)        256
# _________________________________________________________________
# re_lu_32 (ReLU)              (None, 28, 28, 64)        0
# _________________________________________________________________
# conv_two_transpose_25 (ConvT (None, 28, 28, 32)        51200
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 28, 28, 32)        128
# _________________________________________________________________
# re_lu_33 (ReLU)              (None, 28, 28, 32)        0
# _________________________________________________________________
# conv_two_transpose_26 (ConvT (None, 28, 28, 1)         800
# _________________________________________________________________
# tf.math.tanh_1 (TFOpLambda)  (None, 28, 28, 1)         0
# =================================================================
# Total params: 1,319,584
# Trainable params: 1,306,592
# Non-trainable params: 12,992
# _________________________________________________________________
